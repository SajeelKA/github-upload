# %%
from skimage.segmentation import slic
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
thePath='/home/adimn/Documents/PostMEng/images/'
files=os.listdir(thePath)
t=cv.imread(thePath+files[1])

# %%
t=np.array(t)
plt.imshow(t)

# %%
superT=slic(t)

# %%
superT.shape
# Out:
# (480, 640)

# %%
plt.imshow(superT)

# %%
t.shape
# Out:
# (480, 640, 3)
